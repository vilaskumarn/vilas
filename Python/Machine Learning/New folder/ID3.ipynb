# %% [markdown]
# ![image.png](attachment:8e63c08e-58fe-4a6e-869a-bcdbebbdfd23.png)

# %%
GroundType = [
    "Grass", "Grass", "Turf", "Clay", "Grass",
    "Turf", "Clay", "Grass", "Turf", "Clay",
    "Grass", "Turf", "Clay", "Grass", "Turf",
    "Clay", "Grass", "Turf", "Clay", "Grass"
]

MatchTime = [
    "Morning", "Evening", "Morning", "Afternoon", "Afternoon",
    "Evening", "Morning", "Morning", "Afternoon", "Evening",
    "Evening", "Morning", "Afternoon", "Morning", "Evening",
    "Morning", "Afternoon", "Morning", "Evening", "Morning"
]

TeamStrength = [
    "Strong", "Weak", "Strong", "Average", "Weak",
    "Strong", "Average", "Average", "Strong", "Weak",
    "Average", "Weak", "Strong", "Weak", "Average",
    "Strong", "Average", "Strong", "Average", "Strong"
]

CoachAvailable = [
    "Yes", "No", "Yes", "Yes", "No",
    "Yes", "No", "Yes", "No", "No",
    "Yes", "No", "Yes", "Yes", "Yes",
    "Yes", "No", "Yes", "Yes", "No"
]

PlayCricket = [
    "Yes", "No", "Yes", "Yes", "No",
    "Yes", "No", "Yes", "Yes", "No",
    "Yes", "No", "Yes", "No", "Yes",
    "Yes", "No", "Yes", "Yes", "Yes"
]

# %%
data = {
    "GroundType": GroundType,
    "MatchTime": MatchTime,
    "TeamStrength": TeamStrength,
    "CoachAvailable": CoachAvailable,
    "PlayCricket": PlayCricket
}

# %%
import numpy as np
import pandas as pd

# %%
Y_PC=0
N_PC=0
for i in PlayCricket:
    if i == 'Yes':
        Y_PC +=1
    else:
        N_PC += 1
print(Y_PC,N_PC)
# Out:
# 13 7

# %%
total = Y_PC+N_PC
total
# Out:
# 20

# %%
# Probability

# P(Yes) = 13/20
# P(No) = 7/20

P_Y = 13/20
P_N = 7/20
print(P_Y,P_N)
# Out:
# 0.65 0.35

# %%
# entropy

import math

E_T = -1*(P_Y*(math.log2(P_Y)))-1*(P_N*(math.log2(P_N)))
round(E_T,2)
# Out:
# 0.93
