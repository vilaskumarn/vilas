# %%
import pandas as pd

data = {'Color': ['Red', 'Blue', 'Green', 'Blue']}
df = pd.DataFrame(data)

df_encoded = pd.get_dummies(df, columns=['Color'], prefix='Prefix')

print(df_encoded)
# Out:
#    Prefix_Blue  Prefix_Green  Prefix_Red
# 0        False         False        True
# 1         True         False       False
# 2        False          True       False
# 3         True         False       False

# %%
df
# Out:
#    Color
# 0    Red
# 1   Blue
# 2  Green
# 3   Blue

# %%
from sklearn.preprocessing import OneHotEncoder

encoder=OneHotEncoder(sparse_output=True)
cat_cols=df.columns
en_df=encoder.fit_transform(df[cat_cols])
print(en_df)

# categorical_columns = df.select_dtypes(include=['object']).columns

# encoder = OneHotEncoder(sparse_output=False)

# encoded_data = encoder.fit_transform(df[categorical_columns])

# print(encoded_data)
# Out:
#   (0, 2)	1.0
#   (1, 0)	1.0
#   (2, 1)	1.0
#   (3, 0)	1.0
