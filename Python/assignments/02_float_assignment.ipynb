# %%
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577
print("Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577")
# Out:
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577

# %%
num=[3.14, 2.718, 1.618, 0.577]
res=0
for i in num:
    res+=i
avg=res/len(num)
print(f"The average of 3.14, 2.718, 1.618, 0.577 is : {avg}")
# Out:
# The average of 3.14, 2.718, 1.618, 0.577 is : 2.01325

# %%
# Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)
print("\nQuestion 2: Convert 98.6 Fahrenheit to Celsius")
# Out:
# Question 2: Convert 98.6 Fahrenheit to Celsius

# %%
celsius=(98.6-32)/(1.8)
print(f"98.6 Fahrenheit is {celsius} Celsius")
# Out:
# 98.6 Fahrenheit is 36.99999999999999 Celsius

# %%
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years f:- A = P (1 + r/n)^(nt)
print("\nQuestion 3: Calculate compound interest on $1000 at 5.5% for 3 years")
# Out:
# Question 3: Calculate compound interest on $1000 at 5.5% for 3 years

# %%
p=1000
r=5.5
n=1
t=3

ci=p*((1+((r/100)/n))**(n*t))

print(f"Compound interest on $1000 at 5.5% for 3 years is : ${ci}")
# Out:
# Compound interest on $1000 at 5.5% for 3 years is : $1174.2413749999998

# %%
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2
print("\nQuestion 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2")
# Out:
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2

# %%
# formula : - Hypotenuse (c) = √(a² + b²)

a=3.5
b=4.2
hypo=((a**2)+(b**2))**0.5
print(f"Hypotenuse of a right triangle with sides 3.5 and 4.2 is : {hypo}")
# Out:
# Hypotenuse of a right triangle with sides 3.5 and 4.2 is : 5.4671747731346585

# %%
# Question 5: Calculate the volume of a sphere with radius 7.8
print("\nQuestion 5: Calculate the volume of a sphere with radius 7.8")
# Out:
# Question 5: Calculate the volume of a sphere with radius 7.8

# %%
# volume = (4/3) · π · r3

import math
r=7.8
volume=(4/3)*(math.pi)*((r)**3)
print(f"Volume of a sphere with radius 7.8 is : {volume})")
# Out:
# Volume of a sphere with radius 7.8 is : 1987.798769261791)

# %%
# Question 6: Round 3.14159 to 3 decimal places
print("\nQuestion 6: Round 3.14159 to 3 decimal places")
# Out:
# Question 6: Round 3.14159 to 3 decimal places

# %%
num=3.14159
print(f"Round 3.14159 to 3 decimal places is : {round(num,3)}")
# Out:
# Round 3.14159 to 3 decimal places is : 3.142

# %%
# Question 7: Calculate the percentage: 45 out of 67
print("\nQuestion 7: Calculate the percentage: 45 out of 67")
# Out:
# Question 7: Calculate the percentage: 45 out of 67

# %%
per=(45/67)*100
print(f"The percentage: 45 out of 67 is : {round(per,2)}")
# Out:
# The percentage: 45 out of 67 is : 67.16

# %%
# Question 8: Find the square root of 23.456
print("\nQuestion 8: Find the square root of 23.456")
# Out:
# Question 8: Find the square root of 23.456

# %%
sqrt=(23.456)**0.5
print(f"The square root of 23.456 is : {round(sqrt,2)}")
# Out:
# The square root of 23.456 is : 4.84

# %%
# Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years
print("\nQuestion 9: Calculate simple interest: Principal=2500, Rate=6.5%, Time=2.5 years")
# Out:
# Question 9: Calculate simple interest: Principal=2500, Rate=6.5%, Time=2.5 years

# %%
p=2500
r=6.5/100
t=2.5

si=(p*t*r)
print(f"Simple interest: Principal=2500, Rate=6.5%, Time=2.5 years is : {si}")
# Out:
# Simple interest: Principal=2500, Rate=6.5%, Time=2.5 years is : 406.25

# %%
# Question 10: Convert 45.7 degrees to radians
print("\nQuestion 10: Convert 45.7 degrees to radians")
# Out:
# Question 10: Convert 45.7 degrees to radians

# %%
d=45.7
rad=(45.7*math.pi)/180
print(f"45.7 degrees in radians is : {round(rad,3)}")
# Out:
# 45.7 degrees in radians is : 0.798

# %%
#Radians to Degree
rad=float(input("Enter the radians :"))
d=(rad*180)/math.pi
print(f"{rad} degrees in degrees is : {round(d,1)}")
# Out:
# Enter the radians : 0.798
# 0.798 degrees in degrees is : 45.7
