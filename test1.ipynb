# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Enter a number")
a=int(input())
# Out:
# Enter a number

# %% [markdown]
# taking inputs is not possible.
# when we use a input function to get an input from the user, it doesn't run as python is a interpretor, because of which it falls into a never ending loop and has to be restarted or force stop it.

# %%
a=2
b=3
print(f"Sum of the above two values: {a+b}")
